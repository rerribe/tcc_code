# %%
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,5)

# %%
def funcao(x):
    y = x*np.sin(10*x*np.pi)+2.0
    return y
#((x**2) + x - 1 )

# %%
hv = np.vectorize(funcao)

# %%
def simulated_annealing(espaco_de_busca, temperatura, funcao):
    ponto_inicial = np.random.choice(espaco_de_busca)
    solucao_inicial = funcao(ponto_inicial)
    print("ponto inicial:",ponto_inicial,"solucao inicial:",solucao_inicial)
    history = [ponto_inicial]
    temperatura_hist = [temperatura]
    temperatura_final = 1
    while temperatura > temperatura_final:
        for i in range(1000):
            #print("==========================================================")
            novo_ponto = np.random.choice(espaco_de_busca)
            nova_solucao = funcao(novo_ponto)
            #print("novo ponto:",novo_ponto,"nova solucao:", nova_solucao)
            #print("solucao atual:",solucao_inicial)
            #print("nova solucao:", nova_solucao)
            #print("delta",nova_solucao-solucao_inicial)
            probabilidade = np.random.normal()
            if (nova_solucao-solucao_inicial) < 0 or probabilidade < np.log(-(nova_solucao-solucao_inicial)/temperatura):
                solucao_inicial = nova_solucao
            #else:
            #    
            #    if probabilidade < np.log(-(nova_solucao-solucao_inicial)/temperatura):
            #        print("probabilidade aceita:", probabilidade)
            #        solucao_inicial = nova_solucao
            temperatura_hist.append(temperatura)
            history.append(solucao_inicial)
            #print("nova solucao:", nova_solucao)
        temperatura = temperatura-1
        #print("ponto:", novo_ponto)
        print("solucao ",solucao_inicial," na temperatura ", temperatura)
        
        
        #print("==========================================================")
    print("solucao:",solucao_inicial)
        
    return solucao_inicial, history, temperatura_hist

# %%
espaco_de_busca = np.linspace(-10, 10, 10000)
#plt.plot(X, hv(X))
temperatura = 100
#espaco_de_busca = np.linspace(0,2, num = 1000)
x, history, temperatura_hist = simulated_annealing(espaco_de_busca,temperatura, funcao)
plt.plot(espaco_de_busca, hv(espaco_de_busca))
plt.plot(history, hv(history))
#plt.plot(history, history)
#plt.plot( temperatura_hist)
# Out:
# ponto inicial: -1.5471547154715477 solucao inicial: 0.45902211539712634
# solucao  -7.932451338118222  na temperatura  99
# solucao  -7.932451338118222  na temperatura  98
# solucao  -7.932451338118222  na temperatura  97
# solucao  -7.932451338118222  na temperatura  96
# /home/reinaldo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: invalid value encountered in log
# /home/reinaldo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: RuntimeWarning: divide by zero encountered in log
# solucao  -7.932451338118222  na temperatura  95
# solucao  -7.932451338118222  na temperatura  94
# solucao  -7.932451338118222  na temperatura  93
# solucao  -7.949994876722252  na temperatura  92
# solucao  -7.949994876722252  na temperatura  91
# solucao  -7.949994876722252  na temperatura  90
# solucao  -7.949994876722252  na temperatura  89
# solucao  -7.949994876722252  na temperatura  88
# solucao  -7.949994876722252  na temperatura  87
# solucao  -7.949994876722252  na temperatura  86
# solucao  -7.949994876722252  na temperatura  85
# solucao  -7.949994876722252  na temperatura  84
# solucao  -7.949994876722252  na temperatura  83
# solucao  -7.949994876722252  na temperatura  82
# solucao  -7.949994876722252  na temperatura  81
# solucao  -7.949994876722252  na temperatura  80
# solucao  -7.949994876722252  na temperatura  79
# solucao  -7.949994876722252  na temperatura  78
# solucao  -7.949994876722252  na temperatura  77
# solucao  -7.949994876722252  na temperatura  76
# solucao  -7.949994876722252  na temperatura  75
# solucao  -7.949994876722252  na temperatura  74
